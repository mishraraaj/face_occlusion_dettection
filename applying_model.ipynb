# %%
import cv2
def prepare(filepath):
    IMG_SIZE = 64
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE) 
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
import os

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import keras
import numpy as np

new_model=keras.models.load_model('/content/drive/My Drive/face_oclusion/new_face_oclusion_model.h5')

new_model.load_weights('/content/drive/My Drive/face_oclusion/new_face_oclusion_model_weights.h5')

# %%
path1='/content/drive/My Drive/face_oclusion/New folder (2)'

# %%
prediction=[]
for i in os.listdir(path1):
    prediction.append(np.argmax( new_model.predict([prepare(os.path.join(path1,i))])))

# %%
l=['Maked','open']

# %%
path1='/content/drive/My Drive/face_oclusion/New folder (2)'
path2='/content/drive/My Drive/face_oclusion/pred1'
face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_frontalface_default.xml')
for i,j  in  enumerate(os.listdir(path1)):

    img=cv2.imread(os.path.join(path1,j))


    gray = cv2.cvtColor(im1, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)



    for (x,y,w,h) in faces:
        img = cv2.rectangle(img,(x-2,y-2),(x+w,y+h),(255,0,0),5)
        cv2.putText(img,l[int(prediction[i])],(5,85),2,1,(0,0,255),1,cv2.LINE_AA)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        cv2.imwrite(os.path.join(path2,j),img)
plt.grid(None)  
plt.xticks([])
plt.yticks([])
plt.imshow(img)
